# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
df = pd.read_csv("Outlook_weatherr.csv")
df
# Out:
#     Day   Outlook Temp. Humidity    Wind Decision
# 0     1     Sunny   Hot     High    Weak       No
# 1     2     Sunny   Hot     High  Strong       No
# 2     3  Overcast   Hot     High    Weak      Yes
# 3     4      Rain  Mild     High    Weak      Yes
# 4     5      Rain  Cool   Normal    Weak      Yes
# 5     6      Rain  Cool   Normal  Strong       No
# 6     7  Overcast  Cool   Normal  Strong      Yes
# 7     8     Sunny  Mild     High    Weak       No
# 8     9     Sunny  Cool   Normal    Weak      Yes
# 9    10      Rain  Mild   Normal    Weak      Yes
# 10   11     Sunny  Mild   Normal  Strong      Yes
# 11   12  Overcast  Mild     High  Strong      Yes
# 12   13  Overcast   Hot   Normal    Weak      Yes
# 13   14      Rain  Mild     High  Strong       No

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline 

# plt.scatter(df.Wind	,df.Decision,color='red',marker = '+')

# %%
dfx = df.drop("Day", axis=1)
dfx
# Out:
#      Outlook Temp. Humidity    Wind Decision
# 0      Sunny   Hot     High    Weak       No
# 1      Sunny   Hot     High  Strong       No
# 2   Overcast   Hot     High    Weak      Yes
# 3       Rain  Mild     High    Weak      Yes
# 4       Rain  Cool   Normal    Weak      Yes
# 5       Rain  Cool   Normal  Strong       No
# 6   Overcast  Cool   Normal  Strong      Yes
# 7      Sunny  Mild     High    Weak       No
# 8      Sunny  Cool   Normal    Weak      Yes
# 9       Rain  Mild   Normal    Weak      Yes
# 10     Sunny  Mild   Normal  Strong      Yes
# 11  Overcast  Mild     High  Strong      Yes
# 12  Overcast   Hot   Normal    Weak      Yes
# 13      Rain  Mild     High  Strong       No

# %%
df[df['Outlook']=='Overcast']
df.values
dff = dfx.values.tolist()
dff
# Out:
# [['Sunny', 'Hot', 'High', 'Weak', 'No'],
#  ['Sunny', 'Hot', 'High', 'Strong', 'No'],
#  ['Overcast', 'Hot', 'High', 'Weak', 'Yes'],
#  ['Rain', 'Mild', 'High', 'Weak', 'Yes'],
#  ['Rain', 'Cool', 'Normal', 'Weak', 'Yes'],
#  ['Rain', 'Cool', 'Normal', 'Strong', 'No'],
#  ['Overcast', 'Cool', 'Normal', 'Strong', 'Yes'],
#  ['Sunny', 'Mild', 'High', 'Weak', 'No'],
#  ['Sunny', 'Cool', 'Normal', 'Weak', 'Yes'],
#  ['Rain', 'Mild', 'Normal', 'Weak', 'Yes'],
#  ['Sunny', 'Mild', 'Normal', 'Strong', 'Yes'],
#  ['Overcast', 'Mild', 'High', 'Strong', 'Yes'],
#  ['Overcast', 'Hot', 'Normal', 'Weak', 'Yes'],
#  ['Rain', 'Mild', 'High', 'Strong', 'No']]

# %%
#======================================================
class DecisionTree:
    def __init__(self,startingPoint,dataset,dfx):#----------------------Constructor--------------
        self.startingPoint=startingPoint
        self.dataset=dataset
        self.dfx = dfx
    
    #-----------------------------------------------------    
    unique=[]
    def lst(self,i):
        features = []
        for j in range(len(self.dataset)):
            features.append(self.dataset[j][i])
        return(features)
    #-----------------------------------------------------
    def uniqueee(self,i):
        unique=[]
        for word in self.lst(i):
            if word not in unique:
                unique.append(word) 
            
        return(unique)  
        #---------------------------------------------------
    u=0 
    def Gini(self):
        tbl={}
        total = 0
        #------------------------------------------------------------
        for i in range(self.startingPoint,len(self.dataset[0])-1):
            
            total_gini=0
            #--------------------------------------------------------
            for u in range(len(self.uniqueee(i))):
                print(self.uniqueee(i))
                total_gini_index=0
                s_y = 0
                s_n = 0
                counting = 0
                #---------------------------------------------------
                for j in range(len(self.dataset)):
                    if (self.dataset[j][i] == self.uniqueee(i)[u] and self.dataset[j][-1]=='Yes'):#------ Yes  Counter 
                        s_y +=1
                        counting+=1
                    if (self.dataset[j][i] == self.uniqueee(i)[u] and self.dataset[j][-1]=='No'):#-------  No   Counter 
                        s_n +=1
                        counting+=1
                
                #-------------------------------------------------
                Gini = 1-(s_y/counting)**2 - (s_n/counting)**2
                probability = (counting/len(self.dataset)) * Gini 
                #--------------------------------------------------
                total_gini += probability
          
            
            clm = list(dfx.columns)
            tbl[clm[i]] = total_gini
        
        x=min(tbl, key=tbl.get)
        print(x)    
        Tree=self.dfx[[x,'Decision']].values.tolist()
        obj2 = yesNo(Tree,x)
        print(obj2.Best())

        
print(dff)
obj = DecisionTree(0,dff,dfx)
obj.Gini();
# Out:
# [['Sunny', 'Hot', 'High', 'Weak', 'No'], ['Sunny', 'Hot', 'High', 'Strong', 'No'], ['Overcast', 'Hot', 'High', 'Weak', 'Yes'], ['Rain', 'Mild', 'High', 'Weak', 'Yes'], ['Rain', 'Cool', 'Normal', 'Weak', 'Yes'], ['Rain', 'Cool', 'Normal', 'Strong', 'No'], ['Overcast', 'Cool', 'Normal', 'Strong', 'Yes'], ['Sunny', 'Mild', 'High', 'Weak', 'No'], ['Sunny', 'Cool', 'Normal', 'Weak', 'Yes'], ['Rain', 'Mild', 'Normal', 'Weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'Strong', 'Yes'], ['Overcast', 'Mild', 'High', 'Strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'Weak', 'Yes'], ['Rain', 'Mild', 'High', 'Strong', 'No']]
# ['Sunny', 'Overcast', 'Rain']
# ['Sunny', 'Overcast', 'Rain']
# ['Sunny', 'Overcast', 'Rain']
# ['Hot', 'Mild', 'Cool']
# ['Hot', 'Mild', 'Cool']
# ['Hot', 'Mild', 'Cool']
# ['High', 'Normal']
# ['High', 'Normal']
# ['Weak', 'Strong']
# ['Weak', 'Strong']
# Outlook
# 0.17142857142857143
# ['Sunny']
# ['Hot', 'Mild', 'Cool']
# ['Hot', 'Mild', 'Cool']
# ['Hot', 'Mild', 'Cool']
# ...

# %%
#======================================================
#Tree=dfx[['Outlook','Decision']].values.tolist()
nextNode = []

class yesNo:
    def __init__(self,Tree,x):
        self.dataset=Tree
        self.minimum=x
        
    
    unique=[]
    def lst(self,i):
        features = []
        for j in range(len(self.dataset)):
            features.append(self.dataset[j][i])
        return(features)
    #-----------------------------------------------------
    def uniqueee(self,i):
        unique=[]
        for word in self.lst(i):
            if word not in unique:
                unique.append(word) 
        #print(unique)
        return(unique)    
    
#     for i in range(1,len(self.dataset[0])-1): # just for printing unique values hehehe
#         print(uniqueee(i))

        #---------------------------------------------------
    u=0
    def Best(self):
        
        Right = 0
        Left = 0
        total = 0
        tbl={}
         #--------------------------------------------
        for i in range (len(self.dataset[0])-1):
            total_gini=0
            
             #--------------------------------------------
            for u in range(len(self.uniqueee(i))):
                total_gini_index=0
                s_y = 0
                s_n = 0
                counting = 0
                
                 #--------------------------------------------
                for j in range(len(self.dataset)):
                    if (self.dataset[j][i] == self.uniqueee(i)[u] and self.dataset[j][-1]=='Yes'):#-----------Yes counter
                        s_y +=1
                        counting+=1
        
                    if (self.dataset[j][i] == self.uniqueee(i)[u] and self.dataset[j][-1]=='No'):#-------------No counter
                        s_n +=1
                        counting+=1
                      
                Gini = 1-(s_y/counting)**2 - (s_n/counting)**2
                probability = (counting/len(self.dataset)) * Gini 
                print(probability)
                
                if (probability == 0):
     
                    Right = 1-(s_y/counting)**2 
                    Left  = 1-(s_n/counting)**2
                    if (Right < Left):
                        print(" is yes for---------",self.uniqueee(i)[u])#------------- check Yes 
                        
                    elif( Right>Left):
                        print(" is No for---------",self.uniqueee(i)[u])#------------- check No
                        
                else:
                    SendingForFurtherSiplit=dfx[dfx[self.minimum]==self.uniqueee(i)[u]]
                    SendingForFurtherSipliting=SendingForFurtherSiplit.values.tolist()
                 
                    
                    siplitObj=DecisionTree(u,SendingForFurtherSipliting,SendingForFurtherSiplit)
                    siplitObj.Gini()
                    
                
                   
#                     nextNode.append(x)                    
#             for k in range(len(nextNode)):      
#                 print(dfx[dfx[nextNode[k]]==self.uniqueee(i)[u]])
                                                            
#obj1.uniqueee();
#obj1.nextNode
